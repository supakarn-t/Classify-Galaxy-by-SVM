# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
path = 'SDSS_DR16_90cutoff_for_Vicky.csv'
df = pd.read_csv(path)

# %%
# loc ต้องใช้ชื่อแถว,คอลัมน์
# iloc ใช้แค่ตัวเลขตำแหน่ง
rs = df.loc[:, 'z']
Types = df.loc[:, 'Types']
types = Types.apply(lambda v: v.replace(
    'elliptical', '1').replace('spiral', '0')).astype(int)
fd = df.loc[:, 'fracDeV_r']
#zh8 = df.loc[df.loc[:, 'fracDeV_r'] >= 0.8, 'z']
#zl8 = df.loc[df.loc[:, 'fracDeV_r'] < 0.8, 'z']
u = df.loc[:, 'petroMag_u']
g = df.loc[:, 'petroMag_g']
r = df.loc[:, 'petroMag_r']
i = df.loc[:, 'petroMag_i']
z = df.loc[:, 'petroMag_z']
ur = u-r

# %%
plt.scatter(Types, fd, c='#ff8594')

# %%
plt.figure(figsize=(8, 6), facecolor='none')  # size กราฟ & สีข้างนอก
xlim = [14.4, 18]  # ขอบเขตของแกน
xticks = np.linspace(14.5, 18, 8)  # ขอบเขตของแกนที่โชว์
ylim = [-0.2, 5]
yticks = np.linspace(0, 5, 11)
plt.gca(xlim=xlim, xticks=xticks, ylim=ylim, yticks=yticks)

# scatter=กราฟกระจาย , c=การเปลี่ยนสีของจุด , alpha=ความจางของจุด , s=ขนาดของจุด
plt.scatter(r, ur, c='#ff8594', alpha=1, s=5)

plt.xlabel('r band', fontsize='14')  # ชื่อแกน x
plt.ylabel('u-r band', fontsize='14')  # ชื่อแกน y
plt.minorticks_on()  # ขีดย่อย
plt.tick_params(which='both', labelsize='12',
                direction='in', top='1', right='1')
plt.tick_params(which='major',  length=6, width=1)
plt.tick_params(which='minor',  length=3, width=0.5)

# %%
plt.figure(figsize=(8, 6), facecolor='none')
xlim = [-0.005, 0.205]
xticks = np.linspace(0, 0.2, 9)
ylim = [0, 15000]
yticks = np.linspace(0, 15000, 7)
plt.gca(xlim=xlim, xticks=xticks, ylim=ylim, yticks=yticks)

plt.hist(rs.astype('float'), bins=100, color='#ff8594')  # bins=แบ่งเป็นกี่ช่อง

plt.xlabel('Redshift (z)', fontsize='14')
plt.ylabel('Number', fontsize='14')
plt.minorticks_on()
plt.tick_params(which='both', labelsize='12',
                direction='in', top='1', right='1')
plt.tick_params(which='major',  length=6, width=1)
plt.tick_params(which='minor',  length=3, width=0.5)

# %%
plt.figure(figsize=(8, 6), facecolor='none')
xlim = [-0.005, 0.205]
xticks = np.linspace(0, 0.2, 9)
ylim = [1, 100000]
yticks = np.linspace(1, 100000)
plt.gca(xlim=xlim, xticks=xticks, ylim=ylim, yticks=yticks)

plt.hist(rs.astype('float'), bins=100, color='#ff8594')
plt.yscale('log')

plt.xlabel('Redshift (z)', fontsize='14')
plt.ylabel('Number', fontsize='14')
plt.minorticks_on()
plt.tick_params(which='both', labelsize='12',
                direction='in', top='1', right='1')
plt.tick_params(which='major',  length=6, width=1)
plt.tick_params(which='minor',  length=3, width=0.5)

# %%
Types = df.loc[0:20, 'Types']
types = Types.apply(lambda v: v.replace(
    'elliptical', '1').replace('spiral', '0')).astype(int)
X = np.array(df.loc[0:20, 'petroMag_u':'petroMag_z'])
# u, g, r, i, z band 0, 1, 2, 3, 4
ug = X[:, [0, 1]]
ugx, ugy = ug[:, 0], ug[:, 1]
ur = X[:, [0, 2]]
urx, ury = ur[:, 0], ur[:, 1]
ui = X[:, [0, 3]]
uix, uiy = ui[:, 0], ui[:, 1]
uz = X[:, [0, 4]]
uzx, uzy = uz[:, 0], uz[:, 1]
gr = X[:, [1, 2]]
grx, gry = gr[:, 0], gr[:, 1]
gi = X[:, [1, 3]]
gix, giy = gi[:, 0], gi[:, 1]
gz = X[:, [1, 4]]
gzx, gzy = gz[:, 0], gz[:, 1]
ri = X[:, [2, 3]]
rix, riy = ri[:, 0], ri[:, 1]
rz = X[:, [2, 4]]
rzx, rzy = rz[:, 0], rz[:, 1]
iz = X[:, [3, 4]]
izx, izy = iz[:, 0], iz[:, 1]
y = np.array(types)

# %%
fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(15, 30))

ax[0, 0].scatter(ugx, ugy, c=y, cmap='tab20')
ax[0, 0].set_xlabel('u band', fontsize='14')
ax[0, 0].set_ylabel('g band', fontsize='14')

ax[0, 1].scatter(urx, ury, c=y, cmap='tab20')
ax[0, 1].set_xlabel('u band', fontsize='14')
ax[0, 1].set_ylabel('r band', fontsize='14')

ax[1, 0].scatter(uix, uiy, c=y, cmap='tab20')
ax[1, 0].set_xlabel('u band', fontsize='14')
ax[1, 0].set_ylabel('i band', fontsize='14')

ax[1, 1].scatter(uzx, uzy, c=y, cmap='tab20')
ax[1, 1].set_xlabel('u band', fontsize='14')
ax[1, 1].set_ylabel('z band', fontsize='14')

ax[2, 0].scatter(grx, gry, c=y, cmap='tab20')
ax[2, 0].set_xlabel('g band', fontsize='14')
ax[2, 0].set_ylabel('r band', fontsize='14')

ax[2, 1].scatter(gix, giy, c=y, cmap='tab20')
ax[2, 1].set_xlabel('g band', fontsize='14')
ax[2, 1].set_ylabel('i band', fontsize='14')

ax[3, 0].scatter(gzx, gzy, c=y, cmap='tab20')
ax[3, 0].set_xlabel('g band', fontsize='14')
ax[3, 0].set_ylabel('z band', fontsize='14')

ax[3, 1].scatter(rix, riy, c=y, cmap='tab20')
ax[3, 1].set_xlabel('r band', fontsize='14')
ax[3, 1].set_ylabel('i band', fontsize='14')

ax[4, 0].scatter(rzx, rzy, c=y, cmap='tab20')
ax[4, 0].set_xlabel('r band', fontsize='14')
ax[4, 0].set_ylabel('z band', fontsize='14')

ax[4, 1].scatter(izx, izy, c=y, cmap='tab20')
ax[4, 1].set_xlabel('i band', fontsize='14')
ax[4, 1].set_ylabel('z band', fontsize='14')
# Out:
# Text(0, 0.5, 'z band')
